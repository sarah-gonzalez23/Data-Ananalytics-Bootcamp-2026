# %% [markdown]
# ***Task 1: Variable Declaration and Data Types***

# %%
name="Sarah"

# %%
print(name)
# Out:
# Sarah

# %%
type(name)
# Out:
# str

# %%
birth_year=1989+1

# %%
print(birth_year)
# Out:
# 1990

# %%
type(birth_year)
# Out:
# int
