# %% [markdown]
# ***Task 1: Variable Declaration and Data Types***

# %%
name="Sarah"  #string

# %%
print(name)
# Out:
# Sarah

# %%
type(name)
# Out:
# str

# %%
birth_year=("1990")  #integer

# %%
print(birth_year)
# Out:
# 1990

# %%
type(birth_year)
# Out:
# str

# %%
age=36.5 #float

# %%
print(age)
# Out:
# 36.5

# %%
type(age)
# Out:
# float

# %%
gender=True #boolean

# %%
type(gender)
# Out:
# bool

# %% [markdown]
# ***Task 2: String Manipulation***

# %%
string="Have a great day"

# %%
print(string)
# Out:
# Have a great day

# %%
print(string.lower) #change to lowercase
# Out:
# <built-in method lower of str object at 0x00000198D8867830>

# %%
print(string.replace("day", "morning")) #replace
# Out:
# Have a great morning

# %%
print(string.split(",")) #split into list
# Out:
# ['Have a great day']

# %% [markdown]
# ***Task 3: Basic Operations***

# %%
a,b = 5,2

# %%
print(a+b, a-b, a*b, a/b, a%b, a**b) #basic arithmetic
# Out:
# 7 3 10 2.5 1 25

# %%
print(a>b, a<b, a==b, a!=b, a>=b, a<=b) #comparison
# Out:
# True False False True True False

# %%
print(a>12 and b<3, a<20 or b>4, not (a==b)) #logical
# Out:
# False True True

# %% [markdown]
# ***Task 4: Data Collections***

# %%
this_is_my_list=["One", "Two", "Three", "Four"]
this_is_my_dictionary={"name":"Sarah", "age":36}
this_is_my_tuple=(1,23,56)

# %%
print(this_is_my_list[2]) #access element from list
# Out:
# Three

# %%
print(this_is_my_dictionary["name"]) #access element from dictionary
# Out:
# Sarah

# %%
print(this_is_my_tuple[2]) #access element from tuple
# Out:
# 56

# %% [markdown]
# ***Task 5: Expression Combination***

# %%
result=(age*age)/(a-b)+ len(name)

# %%
print("Final result:", result)
# Out:
# Final result: 449.0833333333333
